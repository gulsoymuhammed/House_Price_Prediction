# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df=pd.read_csv("CSV PATH ")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
zero=len(df[df["waterfront"]==0])
one=len(df[df["waterfront"]==1])
wf=[zero,one]
labels=["none waterfront","waterfront"]
colors=["brown","blue"]
plt.figure(figsize=(5,5))
plt.bar(labels,wf,color=colors)
# Out:
# <BarContainer object of 2 artists>

# %%
#we can understand that there are not missing values
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
label=["id","date","sqft_lot15","sqft_living15","long","lat","zipcode","yr_renovated","yr_built","sqft_basement"]
df.drop(labels=label,axis=1,inplace=True)

# %%
df.drop(labels=["waterfront","view"],axis=1,inplace=True)

# %%
df.drop(labels=["condition"],axis=1,inplace=True)

# %%
df.describe().round()
# Out:
#            price  bedrooms  bathrooms  sqft_living   sqft_lot   floors  \
# count    21613.0   21613.0    21613.0      21613.0    21613.0  21613.0
# mean    540088.0       3.0        2.0       2080.0    15107.0      1.0
# std     367127.0       1.0        1.0        918.0    41421.0      1.0
# min      75000.0       0.0        0.0        290.0      520.0      1.0
# 25%     321950.0       3.0        2.0       1427.0     5040.0      1.0
# 50%     450000.0       3.0        2.0       1910.0     7618.0      2.0
# 75%     645000.0       4.0        2.0       2550.0    10688.0      2.0
# max    7700000.0      33.0        8.0      13540.0  1651359.0      4.0
#
#          grade  sqft_above
# count  21613.0     21613.0
# mean       8.0      1788.0
# std        1.0       828.0
# min        1.0       290.0
# 25%        7.0      1190.0
# 50%        7.0      1560.0
# 75%        8.0      2210.0
# max       13.0      9410.0

# %% [markdown]
# bu hatalı incelenecek

# %%
len(df)*0.01
# Out:
# 216.13

# %%
plt.figure(figsize=(7,5))
sbn.distplot(df["price"])
# Out:
# <ipython-input-14-058d1ad30769>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sbn.countplot(x=df["grade"])
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
sbn.countplot(x=df["floors"])
# Out:
# <Axes: xlabel='floors', ylabel='count'>

# %%
df.corr()
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price        1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms     0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms    0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living  0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot     0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors       0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# grade        0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above   0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
#
#                 grade  sqft_above
# price        0.667434    0.605567
# bedrooms     0.356967    0.477600
# bathrooms    0.664983    0.685342
# sqft_living  0.762704    0.876597
# sqft_lot     0.113621    0.183512
# floors       0.458183    0.523885
# grade        1.000000    0.755923
# ...

# %%
df.corr()["grade"].sort_values()
# Out:
# sqft_lot       0.113621
# bedrooms       0.356967
# floors         0.458183
# bathrooms      0.664983
# price          0.667434
# sqft_above     0.755923
# sqft_living    0.762704
# grade          1.000000
# Name: grade, dtype: float64

# %%
from matplotlib import use
from matplotlib.ticker import ScalarFormatter
sbn.scatterplot(x="sqft_living",y="sqft_lot",data=df)
plt.ticklabel_format(style='plain', axis='both')
plt.xlabel("sqft_living")
plt.ylabel("sqft_lot")
# Out:
# Text(0, 0.5, 'sqft_lot')

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors         grade    sqft_above
# count  21613.000000  21613.000000  21613.000000
# mean       1.494309      7.656873   1788.390691
# std        0.539989      1.175459    828.090978
# min        1.000000      1.000000    290.000000
# ...

# %%
df[df["bedrooms"]==33]
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  grade  \
# 15870  640000.0        33       1.75         1620      6000     1.0      7
#
#        sqft_above
# 15870        1040

# %%
df.drop(labels=15870,inplace=True)

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161200e+04  21612.000000  21612.000000  21612.000000  2.161200e+04
# mean   5.400835e+05      3.369471      2.114774   2079.921016  1.510739e+04
# std    3.671351e+05      0.907982      0.770177    918.456818  4.142142e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.218375e+05      3.000000      1.750000   1426.500000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.619000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068825e+04
# max    7.700000e+06     11.000000      8.000000  13540.000000  1.651359e+06
#
#              floors         grade    sqft_above
# count  21612.000000  21612.000000  21612.000000
# mean       1.494332      7.656904   1788.425319
# std        0.539991      1.175477    828.094487
# min        1.000000      1.000000    290.000000
# ...

# %%
update_df=df.sort_values("price",ascending=False).iloc[300:]
plt.figure(figsize=(7,5))
sbn.distplot(update_df["price"])
update_df.describe()
# Out:
# <ipython-input-26-bc65bc347b0c>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(update_df["price"])
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.131200e+04  21312.000000  21312.000000  21312.000000  2.131200e+04
# mean   5.128131e+05      3.356419      2.092424   2042.077421  1.491184e+04
# std    2.721528e+05      0.900332      0.742105    849.469004  4.085936e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.200000e+05      3.000000      1.500000   1420.000000  5.015000e+03
# ...

# %%
update_df.groupby("bathrooms").mean()["price"].round()
# Out:
# bathrooms
# 0.00     448160.0
# 0.50     237375.0
# 0.75     294521.0
# 1.00     347041.0
# 1.25     621217.0
# 1.50     409322.0
# 1.75     452875.0
# 2.00     456987.0
# 2.25     524593.0
# 2.50     543871.0
# 2.75     646112.0
# 3.00     658832.0
# 3.25     846460.0
# 3.50     863752.0
# 3.75    1021370.0
# 4.00     991563.0
# 4.25    1101693.0
# 4.50    1011776.0
# 4.75    1179289.0
# 5.00     996038.0
# 5.25    1105312.0
# 5.50    1316250.0
# 5.75     540000.0
# 6.00    1194000.0
# 6.50    1180000.0
# 6.75     800000.0
# 7.50     450000.0
# Name: price, dtype: float64

# %%
update_df[update_df["bathrooms"]>6].head(15)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  grade  \
# 20578  1180000.0         6       6.50         6260     10955     2.0     11
# 4024    800000.0         7       6.75         7480     41664     2.0     11
# 8546    450000.0         9       7.50         4050      6504     2.0      7
#
#        sqft_above
# 20578        4840
# 4024         5080
# 8546         4050

# %%
len(update_df)
# Out:
# 21312

# %%
update_df.drop(index=8546,axis=1,inplace=True)

# %%
len(update_df)
# Out:
# 21311

# %%
df=update_df

# %%
x=df.drop("price",axis=1).values
y=df["price"].values
x,y
# Out:
# (array([[4.00e+00, 3.50e+00, 3.93e+03, ..., 2.00e+00, 1.20e+01, 3.93e+03],
#         [5.00e+00, 3.25e+00, 5.27e+03, ..., 2.00e+00, 1.00e+01, 4.01e+03],
#         [4.00e+00, 3.25e+00, 4.06e+03, ..., 2.00e+00, 1.10e+01, 4.06e+03],
#         ...,
#         [1.00e+00, 7.50e-01, 4.30e+02, ..., 1.00e+00, 4.00e+00, 4.30e+02],
#         [2.00e+00, 1.00e+00, 7.80e+02, ..., 1.00e+00, 5.00e+00, 7.80e+02],
#         [1.00e+00, 0.00e+00, 6.70e+02, ..., 1.00e+00, 3.00e+00, 6.70e+02]]),
#  array([1799000., 1795000., 1795000., ...,   80000.,   78000.,   75000.]))

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape,y_train.shape
# Out:
# ((14917, 7), (14917,))

# %%
from sklearn.preprocessing import MinMaxScaler

mms=MinMaxScaler()
x_train=mms.fit_transform(x_train)
x_test=mms.transform(x_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
x_train.shape
# Out:
# (14917, 7)

# %%
model = Sequential()

model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=x_train,y=y_train,batch_size=128,epochs=400,validation_data=(x_test,y_test))
# Out:
# Epoch 1/400
# 117/117 [==============================] - 2s 6ms/step - loss: 337861115904.0000 - val_loss: 335077146624.0000
# Epoch 2/400
# 117/117 [==============================] - 0s 3ms/step - loss: 337330798592.0000 - val_loss: 333310722048.0000
# Epoch 3/400
# 117/117 [==============================] - 0s 3ms/step - loss: 330504568832.0000 - val_loss: 317392748544.0000
# Epoch 4/400
# 117/117 [==============================] - 0s 3ms/step - loss: 294526550016.0000 - val_loss: 254190862336.0000
# Epoch 5/400
# 117/117 [==============================] - 0s 3ms/step - loss: 199975108608.0000 - val_loss: 133570142208.0000
# Epoch 6/400
# 117/117 [==============================] - 0s 3ms/step - loss: 88747483136.0000 - val_loss: 54821912576.0000
# Epoch 7/400
# 117/117 [==============================] - 0s 3ms/step - loss: 51062771712.0000 - val_loss: 47423700992.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
losses.head()
# Out:
#            loss      val_loss
# 0  3.378611e+11  3.350771e+11
# 1  3.373308e+11  3.333107e+11
# 2  3.305046e+11  3.173927e+11
# 3  2.945266e+11  2.541909e+11
# 4  1.999751e+11  1.335701e+11

# %%
from sklearn.metrics import mean_absolute_error

# %%
predict=model.predict(x_test)
# Out:
# 200/200 [==============================] - 0s 1ms/step

# %%
mean_absolute_error(y_test,predict)
# Out:
# 134178.72791982107

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test,predict)
plt.plot(y_test,y_test,"g*-")
